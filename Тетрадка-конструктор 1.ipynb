# %% [markdown]
# # Предварительные действия

# %%
# импортируем необходимые библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Создание датафрейма из файла Excel и CSV файла

# %% [markdown]
# ## Создаем датафрейм из файла Excel

# %%
data=pd.read_excel("C:/Trees/Credit.xlsx", sheet_name='Credit')

# %% [markdown]
# ## Создаем датафрейм из CSV файла, в котором используется кириллица и значения разделены точками с запятой

# %%
data2 = pd.read_csv("C:/Trees/Example_semicolon.csv", encoding='cp1251', sep=';')
data2.head()
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 0          1      M  48.0            MAR          UMN    59998.00
# 1          2      F  28.0            MAR          UMN    10889.00
# 2          3      M  32.0            MAR          SPC    10728.00
# 3          4      F  27.0            DIV          SPC    12009.09
# 4          5      M  45.0            MAR          SPC    16908.89
#
#    credit_month  tariff_id  score_shk education          living_region  \
# 0            10         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ
# 1             6          2   0.248514       GRD                 МОСКВА
# 2            12          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ
# 3            12          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4            10          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg  \
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0
#
#    avregzarplata
# 0        25850.0
# 1        66880.0
# 2        23430.0
# 3        23650.0
# 4        26620.0

# %% [markdown]
# ## Создаем датафрейм из CSV файла, в котором используется кириллица и значения разделены запятыми

# %%
data3 = pd.read_csv("C:/Trees/Example_comma.csv", encoding='cp1251', sep=',')
data3.head()
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 0          1      M  48.0            MAR          UMN    59998.00
# 1          2      F  28.0            MAR          UMN    10889.00
# 2          3      M  32.0            MAR          SPC    10728.00
# 3          4      F  27.0            DIV          SPC    12009.09
# 4          5      M  45.0            MAR          SPC    16908.89
#
#    credit_month  tariff_id  score_shk education          living_region  \
# 0            10         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ
# 1             6          2   0.248514       GRD                 МОСКВА
# 2            12          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ
# 3            12          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4            10          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0

# %% [markdown]
# # Запись датафрейма в CSV файл и файл Excel

# %% [markdown]
# ## Записываем на основе датафрейма CSV файл, в котором значения разделены запятыми

# %%
data3.to_csv('C:\\Trees\\Example_from_pandas_to_csv_comma.csv', sep=',')

# %% [markdown]
# ## Записываем на основе датафрейма CSV файл, в котором значения разделены точками с запятыми

# %%
data3.to_csv('C:\\Trees\\Example_from_pandas_to_csv_semicolon.csv', sep=';')

# %% [markdown]
# ## Записываем на основе датафрейма файл Excel

# %%
from pandas import ExcelWriter
writer = ExcelWriter('Example_from_pandas_to_xlsx.xlsx')
data3.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# # Общие операции с датафреймом

# %% [markdown]
# ## Вывод общей информации о датафрейме

# %%
# Выводим информацию о количестве строк (наблюдений) и количестве столбцов (переменных)
data3.shape
# Out:
# (170746, 15)

# %%
# Выводим первые 5 наблюдений
data3.head()
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 0          1      M  48.0            MAR          UMN    59998.00
# 1          2      F  28.0            MAR          UMN    10889.00
# 2          3      M  32.0            MAR          SPC    10728.00
# 3          4      F  27.0            DIV          SPC    12009.09
# 4          5      M  45.0            MAR          SPC    16908.89
#
#    credit_month  tariff_id  score_shk education          living_region  \
# 0            10         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ
# 1             6          2   0.248514       GRD                 МОСКВА
# 2            12          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ
# 3            12          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4            10          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0

# %%
# Выводим последние 5 наблюдений
data3.tail()
# Out:
#         client_id gender   age marital_status job_position  credit_sum  \
# 170741     170742      F  27.0            UNM          SPC    64867.00
# 170742     170743      F  24.0            MAR          SPC    17640.00
# 170743     170744      F  31.0            UNM          SPC    27556.47
# 170744     170745      F  53.0            DIV          PNA     6189.00
# 170745     170746      M  49.0            MAR          SPC    12787.00
#
#         credit_month  tariff_id  score_shk education         living_region  \
# 170741            12          2   0.535257       GRD  РЕСПУБЛИКА ТАТАРСТАН
# 170742             6         28   0.573287       SCH       САНКТ-ПЕТЕРБУРГ
# 170743            10         19   0.416098       GRD       ПРИМОРСКИЙ КРАЙ
# 170744            12          2   0.482595       SCH    ПЕНЗЕНСКАЯ ОБЛАСТЬ
# 170745            10          2   0.316087       GRD    МОСКОВСКАЯ ОБЛАСТЬ
#
#         monthly_income  credit_count  overdue_credit_count  open_account_flg
# 170741         40000.0           6.0                   0.0                 0
# 170742         30000.0           1.0                   0.0                 0
# 170743         40000.0           1.0                   0.0                 0
# 170744         31000.0           2.0                   0.0                 0
# 170745         40000.0           3.0                   0.0                 0

# %% [markdown]
# ## Отбор определенных столбцов и строк

# %%
# Обратимся к 4-му наблюдению в переменной age, сначала указывается название столбца, 
# затем указывается номер строки, нумерация строк в pandas начинается с 0
data3['age'][3]
# Out:
# 27.0

# %%
# Обратимся к 4-му наблюдению в переменной age иным способом, сначала указав 
# номер строки, затем название столбца
data3.at[3, 'age']
# Out:
# 27.0

# %%
# Отбираем столбцы age и marital_status
data3.filter(items=['age', 'marital_status']).head(10)
# Out:
#     age marital_status
# 0  48.0            MAR
# 1  28.0            MAR
# 2  32.0            MAR
# 3  27.0            DIV
# 4  45.0            MAR
# 5  37.0            MAR
# 6   NaN            MAR
# 7  26.0            UNM
# 8  23.0            NaN
# 9  32.0            UNM

# %%
# Отбираем столбцы age и marital_status и записываем в датафрейм data4
age_marstatus_cols = data3.filter(items=['age', 'marital_status'])
age_marstatus_cols.head()
# Out:
#     age marital_status
# 0  48.0            MAR
# 1  28.0            MAR
# 2  32.0            MAR
# 3  27.0            DIV
# 4  45.0            MAR

# %%
# Отбираем строку 5
data3.filter(items=[5], axis=0)
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 5          6      F  37.0            MAR          SPC     26788.0
#
#    credit_month  tariff_id  score_shk education        living_region  \
# 5            10          2   0.484203       SCH  СТАВРОПОЛЬСКИЙ КРАЙ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 5         30000.0           0.0                   0.0                 0

# %%
# Отбираем первые 5 строк
data3[:5]
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 0          1      M  48.0            MAR          UMN    59998.00
# 1          2      F  28.0            MAR          UMN    10889.00
# 2          3      M  32.0            MAR          SPC    10728.00
# 3          4      F  27.0            DIV          SPC    12009.09
# 4          5      M  45.0            MAR          SPC    16908.89
#
#    credit_month  tariff_id  score_shk education          living_region  \
# 0            10         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ
# 1             6          2   0.248514       GRD                 МОСКВА
# 2            12          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ
# 3            12          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4            10          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0

# %%
# Отбираем первые 5 строк в столбцах age и marital_status
data3[['age', 'marital_status']][:5]
# Out:
#     age marital_status
# 0  48.0            MAR
# 1  28.0            MAR
# 2  32.0            MAR
# 3  27.0            DIV
# 4  45.0            MAR

# %%
# Отбираем переменные, в названии которых встречается паттерн credit
data3.filter(like='credit').head(10)
# Out:
#    credit_sum  credit_month  credit_count  overdue_credit_count
# 0    59998.00            10           1.0                   1.0
# 1    10889.00             6           2.0                   0.0
# 2    10728.00            12           5.0                   0.0
# 3    12009.09            12           2.0                   0.0
# 4    16908.89            10           1.0                   0.0
# 5    26788.00            10           0.0                   0.0
# 6    10317.00             6           3.0                   0.0
# 7    47878.00            10           3.0                   0.0
# 8    37577.16            12           3.0                   0.0
# 9    26268.00            10           7.0                   0.0

# %% [markdown]
# ## Сортировка наблюдений

# %%
# Сортируем наблюдения по убыванию значений переменной age
data3.sort_values(by='age', ascending=0).head(10)
# Out:
#         client_id gender   age marital_status job_position  credit_sum  \
# 93819       93820      F  71.0            WID          SPC     20678.0
# 84608       84609      M  71.0            MAR          SPC     18670.0
# 112903     112904      M  71.0            MAR          PNA     14008.0
# 81447       81448      F  71.0            WID          PNA     31307.0
# 3852         3853      F  71.0            WID          PNA     13579.0
# 153147     153148      F  71.0            MAR          PNA      4739.0
# 20991       20992      F  71.0            UNM          PNA      7680.0
# 139312     139313      F  71.0            WID          SPC      5414.0
# 75491       75492      F  71.0            WID          SPC     41303.0
# 95811       95812      F  71.0            DIV          PNA     11929.0
#
#         credit_month  tariff_id  score_shk education            living_region  \
# 93819             12          2   0.493432       GRD       МОСКОВСКАЯ ОБЛАСТЬ
# 84608             12         20   0.499823       SCH      ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
# 112903            10          2   0.381796       UGR          САНКТ-ПЕТЕРБУРГ
# 81447             10         19   0.465620       SCH          РЕСПУБЛИКА ТЫВА
# 3852              10          2   0.543567       SCH      УЛЬЯНОВСКАЯ ОБЛАСТЬ
# 153147            10          2   0.532422       SCH       ТАМБОВСКАЯ ОБЛАСТЬ
# 20991             13          2   0.386022       GRD          КУРСКАЯ ОБЛАСТЬ
# 139312             6          2   0.528093       SCH      ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
# 75491             10         19   0.445599       SCH          САНКТ-ПЕТЕРБУРГ
# 95811             10          2   0.511289       SCH  РЕСПУБЛИКА БАШКОРТОСТАН
#
#         monthly_income  credit_count  overdue_credit_count  open_account_flg
# 93819          38000.0           0.0                   0.0                 1
# 84608          19000.0           2.0                   0.0                 0
# 112903         39000.0           2.0                   0.0                 1
# 81447          16400.0           0.0                   0.0                 1
# 3852           32000.0           0.0                   0.0                 0
# 153147          8700.0           0.0                   0.0                 1
# 20991          16000.0           2.0                   0.0                 1
# 139312         40000.0           0.0                   0.0                 0
# 75491          35000.0           0.0                   0.0                 1
# 95811          18000.0           2.0                   1.0                 1

# %%
# Сортируем наблюдения по возрастанию значений переменной client_id
data3.sort_values(by='client_id', ascending=1).head(10)
# Out:
#    client_id gender   age marital_status job_position  credit_sum  \
# 0          1      M  48.0            MAR          UMN    59998.00
# 1          2      F  28.0            MAR          UMN    10889.00
# 2          3      M  32.0            MAR          SPC    10728.00
# 3          4      F  27.0            DIV          SPC    12009.09
# 4          5      M  45.0            MAR          SPC    16908.89
# 5          6      F  37.0            MAR          SPC    26788.00
# 6          7      M   NaN            MAR          SPC    10317.00
# 7          8      F  26.0            UNM          SPC    47878.00
# 8          9      M  23.0            NaN          SPC    37577.16
# 9         10      F  32.0            UNM          SPC    26268.00
#
#    credit_month  tariff_id  score_shk education          living_region  \
# 0            10         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ
# 1             6          2   0.248514       GRD                 МОСКВА
# 2            12          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ
# 3            12          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4            10          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ
# 5            10          2   0.484203       SCH    СТАВРОПОЛЬСКИЙ КРАЙ
# 6             6         25   0.276012       SCH  НИЖЕГОРОДСКАЯ ОБЛАСТЬ
# 7            10          2   0.512525       GRD     МОСКОВСКАЯ ОБЛАСТЬ
# 8            12         28   0.642267       SCH      ТЮМЕНСКАЯ ОБЛАСТЬ
# 9            10          2   0.465026       GRD    СТАВРОПОЛЬСКИЙ КРАЙ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0
# 5         30000.0           0.0                   0.0                 0
# 6         28000.0           3.0                   0.0                 0
# 7         60000.0           3.0                   0.0                 0
# 8         50000.0           3.0                   0.0                 0
# 9         39500.0           7.0                   0.0                 0

# %% [markdown]
# ## Настройка внешнего вида датафрейма

# %%
# Увеличиваем количество отображаемых столбцов датафрейма
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Получение информации о типах переменных и пропусков в них

# %%
# Выводим информацию о количестве непропущенных 
# значений и типах переменных
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170746 entries, 0 to 170745
# Data columns (total 15 columns):
# client_id               170746 non-null int64
# gender                  170746 non-null object
# age                     170744 non-null float64
# marital_status          170744 non-null object
# job_position            170746 non-null object
# credit_sum              170745 non-null float64
# credit_month            170746 non-null int64
# tariff_id               170746 non-null int64
# score_shk               170743 non-null float64
# education               170743 non-null object
# living_region           170554 non-null object
# monthly_income          170745 non-null float64
# credit_count            161516 non-null float64
# overdue_credit_count    161516 non-null float64
# open_account_flg        170746 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 19.5+ MB

# %% [markdown]
# ##  Удаление переменных

# %%
data3.drop('client_id', axis=1, inplace=True)
data3.head()
# Out:
#   gender   age marital_status job_position  credit_sum  credit_month  \
# 0      M  48.0            MAR          UMN    59998.00            10
# 1      F  28.0            MAR          UMN    10889.00             6
# 2      M  32.0            MAR          SPC    10728.00            12
# 3      F  27.0            DIV          SPC    12009.09            12
# 4      M  45.0            MAR          SPC    16908.89            10
#
#    tariff_id  score_shk education          living_region  monthly_income  \
# 0         28   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0
# 1          2   0.248514       GRD                 МОСКВА         43000.0
# 2          2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0
# 3          2   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0
# 4          2   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0
#
#    credit_count  overdue_credit_count  open_account_flg
# 0           1.0                   1.0                 0
# 1           2.0                   0.0                 0
# 2           5.0                   0.0                 0
# 3           2.0                   0.0                 0
# 4           1.0                   0.0                 0

# %% [markdown]
# ## Получение информации о частотах категорий и уникальных значениях

# %%
# Возьмем переменную marital_status, давайте
# взглянем на частоты ее категорий, по
# умолчанию пропуски не будут выведены
data3['marital_status'].value_counts()
# Out:
# MAR    93955
# UNM    52148
# DIV    16970
# CIV     4196
# WID     3475
# Name: marital_status, dtype: int64

# %%
# Выводим информацию о частотах другим способом
pd.value_counts(data3['marital_status'].values, sort=False)
# Out:
# CIV     4196
# UNM    52148
# MAR    93955
# WID     3475
# DIV    16970
# dtype: int64

# %%
# Теперь с помощью значения False параметра 
# dropna зададим вывод пропусков
data3['marital_status'].value_counts(dropna = False)
# Out:
# MAR    93955
# UNM    52148
# DIV    16970
# CIV     4196
# WID     3475
# NaN        2
# Name: marital_status, dtype: int64

# %%
# Выделяем категориальные переменные в отдельную группу
categorical_columns = [c for c in data3.columns if data3[c].dtype.name == 'object']

# Пробежим по нашим категориальным переменным,
# выводя частоты категорий по каждой
for c in categorical_columns:
    print(data3[c].value_counts(dropna = False))
# Out:
# F    88697
# M    82049
# Name: gender, dtype: int64
# MAR    93955
# UNM    52148
# DIV    16970
# CIV     4196
# WID     3475
# NaN        2
# Name: marital_status, dtype: int64
# SPC    134680
# UMN     17674
# BIS      5591
# PNA      4107
# DIR      3750
# ATP      2791
# WRK       656
# NOR       537
# WOI       352
# INP       241
# BIU       126
# WRP       110
# PNI        65
# PNV        40
# PNS        12
# HSK         8
# INV         5
# ONB         1
# Name: job_position, dtype: int64
# SCH    87536
# GRD    72594
# UGR     9941
# PGR      565
# ACD      107
# NaN        3
# Name: education, dtype: int64
# МОСКОВСКАЯ ОБЛАСТЬ                     12844
# МОСКВА                                  9261
# ТЮМЕНСКАЯ ОБЛАСТЬ                       8735
# КРАСНОДАРСКИЙ КРАЙ                      8355
# САНКТ-ПЕТЕРБУРГ                         8303
# РЕСПУБЛИКА ТАТАРСТАН                    7667
# СВЕРДЛОВСКАЯ ОБЛАСТЬ                    7316
# РЕСПУБЛИКА БАШКОРТОСТАН                 6466
# ЧЕЛЯБИНСКАЯ ОБЛАСТЬ                     5155
# САМАРСКАЯ ОБЛАСТЬ                       5104
# СТАВРОПОЛЬСКИЙ КРАЙ                     4617
# РОСТОВСКАЯ ОБЛАСТЬ                      4328
# ИРКУТСКАЯ ОБЛАСТЬ                       4323
# НИЖЕГОРОДСКАЯ ОБЛАСТЬ                   3695
# ПЕРМСКИЙ КРАЙ                           3614
# ЛЕНИНГРАДСКАЯ ОБЛАСТЬ                   3529
# КРАСНОЯРСКИЙ КРАЙ                       3121
# КЕМЕРОВСКАЯ ОБЛАСТЬ                     2890
# АСТРАХАНСКАЯ ОБЛАСТЬ                    2719
# ВОЛОГОДСКАЯ ОБЛАСТЬ                     2605
# ВОЛГОГРАДСКАЯ ОБЛАСТЬ                   2293
# САРАТОВСКАЯ ОБЛАСТЬ                     2282
# НОВОСИБИРСКАЯ ОБЛАСТЬ                   2169
# АРХАНГЕЛЬСКАЯ ОБЛАСТЬ                   1895
# РЕСПУБЛИКА КОМИ                         1860
# РЕСПУБЛИКА САХА (ЯКУТИЯ)                1857
# ВОРОНЕЖСКАЯ ОБЛАСТЬ                     1723
# РЕСПУБЛИКА БУРЯТИЯ                      1643
# ХАБАРОВСКИЙ КРАЙ                        1560
# ТВЕРСКАЯ ОБЛАСТЬ                        1548
#                                        ...
# ОРЛОВСКАЯ ОБЛАСТЬ                        748
# НОВГОРОДСКАЯ ОБЛАСТЬ                     745
# РЯЗАНСКАЯ ОБЛАСТЬ                        728
# КАЛИНИНГРАДСКАЯ ОБЛАСТЬ                  728
# РЕСПУБЛИКА МОРДОВИЯ                      717
# САХАЛИНСКАЯ ОБЛАСТЬ                      705
# РЕСПУБЛИКА МАРИЙ ЭЛ                      700
# РЕСПУБЛИКА КАРЕЛИЯ                       679
# КИРОВСКАЯ ОБЛАСТЬ                        647
# КАБАРДИНО-БАЛКАРСКАЯ РЕСПУБЛИКА          637
# ТОМСКАЯ ОБЛАСТЬ                          626
# КАРАЧАЕВО-ЧЕРКЕССКАЯ РЕСПУБЛИКА          576
# ПСКОВСКАЯ ОБЛАСТЬ                        575
# РЕСПУБЛИКА ТЫВА                          564
# РЕСПУБЛИКА АДЫГЕЯ                        554
# АЛТАЙСКИЙ КРАЙ                           553
# КОСТРОМСКАЯ ОБЛАСТЬ                      514
# РЕСПУБЛИКА ХАКАСИЯ                       480
# КАМЧАТСКИЙ КРАЙ                          412
# РЕСПУБЛИКА СЕВЕРНАЯ ОСЕТИЯ - АЛАНИЯ      379
# РЕСПУБЛИКА КАЛМЫКИЯ                      305
# ЕВРЕЙСКАЯ АВТОНОМНАЯ ОБЛАСТЬ             203
# NaN                                      192
# МАГАДАНСКАЯ ОБЛАСТЬ                      159
# РЕСПУБЛИКА ДАГЕСТАН                       69
# РЕСПУБЛИКА АЛТАЙ                          54
# ЧУКОТСКИЙ АВТОНОМНЫЙ ОКРУГ                32
# ЧЕЧЕНСКАЯ РЕСПУБЛИКА                      31
# РЕСПУБЛИКА ИНГУШЕТИЯ                      19
# ЧИТИНСКАЯ ОБЛАСТЬ                         17
# Name: living_region, Length: 82, dtype: int64

# %%
# Пробежим по нашим категориальным переменным,
# выводя уникальные значения по каждой
for c in categorical_columns:
    print(data3[c].unique())
# Out:
# ['M' 'F']
# ['MAR' 'DIV' 'UNM' nan 'WID' 'CIV']
# ['UMN' 'SPC' 'INP' 'DIR' 'ATP' 'PNA' 'BIS' 'WOI' 'NOR' 'WRK' 'WRP' 'PNV'
#  'BIU' 'PNI' 'HSK' 'PNS' 'INV' 'ONB']
# ['GRD' 'SCH' nan 'UGR' 'PGR' 'ACD']
# ['КРАСНОДАРСКИЙ КРАЙ' 'МОСКВА' 'САРАТОВСКАЯ ОБЛАСТЬ'
#  'ВОЛГОГРАДСКАЯ ОБЛАСТЬ' 'ЧЕЛЯБИНСКАЯ ОБЛАСТЬ' 'СТАВРОПОЛЬСКИЙ КРАЙ'
#  'НИЖЕГОРОДСКАЯ ОБЛАСТЬ' 'МОСКОВСКАЯ ОБЛАСТЬ' 'ТЮМЕНСКАЯ ОБЛАСТЬ'
#  'САНКТ-ПЕТЕРБУРГ' 'РЕСПУБЛИКА БАШКОРТОСТАН' 'АРХАНГЕЛЬСКАЯ ОБЛАСТЬ'
#  'ПЕРМСКИЙ КРАЙ' 'КАРАЧАЕВО-ЧЕРКЕССКАЯ РЕСПУБЛИКА' 'КАЛУЖСКАЯ ОБЛАСТЬ'
#  'ВОЛОГОДСКАЯ ОБЛАСТЬ' 'РОСТОВСКАЯ ОБЛАСТЬ' 'УДМУРТСКАЯ РЕСПУБЛИКА'
#  'ИРКУТСКАЯ ОБЛАСТЬ' 'БЕЛГОРОДСКАЯ ОБЛАСТЬ' 'КОСТРОМСКАЯ ОБЛАСТЬ'
#  'РЕСПУБЛИКА ХАКАСИЯ' 'РЕСПУБЛИКА ТАТАРСТАН' 'СВЕРДЛОВСКАЯ ОБЛАСТЬ'
#  'ПСКОВСКАЯ ОБЛАСТЬ' 'ЗАБАЙКАЛЬСКИЙ КРАЙ' 'ОРЕНБУРГСКАЯ ОБЛАСТЬ'
#  'ВОРОНЕЖСКАЯ ОБЛАСТЬ' 'АСТРАХАНСКАЯ ОБЛАСТЬ' 'НОВОСИБИРСКАЯ ОБЛАСТЬ'
#  'КУРГАНСКАЯ ОБЛАСТЬ' 'УЛЬЯНОВСКАЯ ОБЛАСТЬ' 'МУРМАНСКАЯ ОБЛАСТЬ'
#  'КРАСНОЯРСКИЙ КРАЙ' 'РЕСПУБЛИКА БУРЯТИЯ' 'РЕСПУБЛИКА САХА (ЯКУТИЯ)'
#  'АМУРСКАЯ ОБЛАСТЬ' 'ХАБАРОВСКИЙ КРАЙ' 'САМАРСКАЯ ОБЛАСТЬ'
#  'ТВЕРСКАЯ ОБЛАСТЬ' 'ЯРОСЛАВСКАЯ ОБЛАСТЬ' 'ВЛАДИМИРСКАЯ ОБЛАСТЬ'
#  'ЛЕНИНГРАДСКАЯ ОБЛАСТЬ' 'ОРЛОВСКАЯ ОБЛАСТЬ' 'КЕМЕРОВСКАЯ ОБЛАСТЬ'
#  'ОМСКАЯ ОБЛАСТЬ' 'ЧЕЧЕНСКАЯ РЕСПУБЛИКА' 'КУРСКАЯ ОБЛАСТЬ'
#  'ТУЛЬСКАЯ ОБЛАСТЬ' 'РЕСПУБЛИКА АДЫГЕЯ' 'РЕСПУБЛИКА КОМИ'
#  'ПРИМОРСКИЙ КРАЙ' 'СМОЛЕНСКАЯ ОБЛАСТЬ' 'КИРОВСКАЯ ОБЛАСТЬ'
#  'РЕСПУБЛИКА ДАГЕСТАН' 'ПЕНЗЕНСКАЯ ОБЛАСТЬ' 'РЕСПУБЛИКА КАРЕЛИЯ'
#  'ТОМСКАЯ ОБЛАСТЬ' 'МАГАДАНСКАЯ ОБЛАСТЬ' 'РЕСПУБЛИКА МАРИЙ ЭЛ'
#  'ИВАНОВСКАЯ ОБЛАСТЬ' 'ЕВРЕЙСКАЯ АВТОНОМНАЯ ОБЛАСТЬ' 'АЛТАЙСКИЙ КРАЙ'
#  'КАБАРДИНО-БАЛКАРСКАЯ РЕСПУБЛИКА' 'ТАМБОВСКАЯ ОБЛАСТЬ' 'РЕСПУБЛИКА ТЫВА'
#  'НОВГОРОДСКАЯ ОБЛАСТЬ' 'ЛИПЕЦКАЯ ОБЛАСТЬ'
#  'РЕСПУБЛИКА СЕВЕРНАЯ ОСЕТИЯ - АЛАНИЯ' 'РЯЗАНСКАЯ ОБЛАСТЬ'
#  'САХАЛИНСКАЯ ОБЛАСТЬ' 'ЧУВАШСКАЯ РЕСПУБЛИКА' nan 'КАМЧАТСКИЙ КРАЙ'
#  'РЕСПУБЛИКА МОРДОВИЯ' 'РЕСПУБЛИКА КАЛМЫКИЯ' 'РЕСПУБЛИКА АЛТАЙ'
#  'БРЯНСКАЯ ОБЛАСТЬ' 'КАЛИНИНГРАДСКАЯ ОБЛАСТЬ' 'ЧУКОТСКИЙ АВТОНОМНЫЙ ОКРУГ'
#  'РЕСПУБЛИКА ИНГУШЕТИЯ' 'ЧИТИНСКАЯ ОБЛАСТЬ']

# %% [markdown]
# # Импутация пропущенных значений

# %%
# Заменяем пропуски в переменной age средним значением
data3['age'].fillna(data3['age'].mean(), inplace=True)

# %%
# Заменяем пропуски в переменной credit_sum медианой
data3['credit_sum'].fillna(data3['credit_sum'].median(), inplace=True)

# %%
# Заменяем пропуски в переменных score_shk и monthly_income медианой, используя цикл
for i in ['score_shk', 'monthly_income']:
    if i in data3.columns:
        data3[i].fillna(data3[i].median(), inplace=True)

# %%
# Заменяем пропуски в переменной education модой - самым часто встречающимся значением
data3['education'].fillna(data3['education'].value_counts().index[0], inplace=True)

# %%
# Записываем пропуски в отдельную категорию nan, 
# просто присвоив тип str
data3['living_region'] = data3['living_region'].astype('str')

# Выведем частоты категорий переменной living_region,
# убедимся, что пропуски сформировали
# отдельную категорию nan
data3['living_region'].value_counts(dropna=False).tail(10)
# Out:
# РЕСПУБЛИКА КАЛМЫКИЯ             305
# ЕВРЕЙСКАЯ АВТОНОМНАЯ ОБЛАСТЬ    203
# nan                             192
# МАГАДАНСКАЯ ОБЛАСТЬ             159
# РЕСПУБЛИКА ДАГЕСТАН              69
# РЕСПУБЛИКА АЛТАЙ                 54
# ЧУКОТСКИЙ АВТОНОМНЫЙ ОКРУГ       32
# ЧЕЧЕНСКАЯ РЕСПУБЛИКА             31
# РЕСПУБЛИКА ИНГУШЕТИЯ             19
# ЧИТИНСКАЯ ОБЛАСТЬ                17
# Name: living_region, dtype: int64

# %%
# Для пропусков в переменной marital_status 
# можно создать отдельную категорию Пропуск
data3['marital_status'] = data3['marital_status'].fillna('Пропуск')

data3['marital_status'].value_counts(dropna=False)
# Out:
# MAR        93955
# UNM        52148
# DIV        16970
# CIV         4196
# WID         3475
# Пропуск        2
# Name: marital_status, dtype: int64

# %%
# Заменяем пропуски в переменных credit_count и overdue_credit_count нулем, используя цикл
for i in ['credit_count', 'overdue_credit_count']:
    if i in data3.columns:
        data3[i].fillna(0, inplace=True)

# %%
# Снова выводим информацию о количестве непропущенных 
# значений и типах переменных
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170746 entries, 0 to 170745
# Data columns (total 14 columns):
# gender                  170746 non-null object
# age                     170746 non-null float64
# marital_status          170746 non-null object
# job_position            170746 non-null object
# credit_sum              170746 non-null float64
# credit_month            170746 non-null int64
# tariff_id               170746 non-null int64
# score_shk               170746 non-null float64
# education               170746 non-null object
# living_region           170746 non-null object
# monthly_income          170746 non-null float64
# credit_count            170746 non-null float64
# overdue_credit_count    170746 non-null float64
# open_account_flg        170746 non-null int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 18.2+ MB

# %% [markdown]
# ## Изменение типов переменных

# %%
# Преобразуем переменные tariff_id и open_account_flg 
# из типа int в тип object, используя цикл
for i in ['tariff_id', 'open_account_flg']:
    if i in data3.columns:
        data3[i]=data3[i].astype('object')

# %%
# Преобразуем переменные age, credit_count и overdue_credit_count 
# из типа float в тип int, используя цикл
for i in ['age', 'credit_count', 'overdue_credit_count']:
    if i in data3.columns:
        data3[i]=data3[i].astype('int')

# %%
# После преобразования типов переменных снова выводим информацию 
# о количестве непропущенных наблюдений в переменных и типах переменных 
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170746 entries, 0 to 170745
# Data columns (total 14 columns):
# gender                  170746 non-null object
# age                     170746 non-null int32
# marital_status          170746 non-null object
# job_position            170746 non-null object
# credit_sum              170746 non-null float64
# credit_month            170746 non-null int64
# tariff_id               170746 non-null object
# score_shk               170746 non-null float64
# education               170746 non-null object
# living_region           170746 non-null object
# monthly_income          170746 non-null float64
# credit_count            170746 non-null int32
# overdue_credit_count    170746 non-null int32
# open_account_flg        170746 non-null object
# dtypes: float64(3), int32(3), int64(1), object(7)
# memory usage: 16.3+ MB

# %% [markdown]
# ## Вывод статистик по переменным

# %%
# По умолчанию метод .describe() выводит информацию
# только по количественным переменным
data3.describe()
# Out:
#                  age     credit_sum   credit_month      score_shk  \
# count  170746.000000  170746.000000  170746.000000  170746.000000
# mean       36.497306   26095.073779      10.980749       0.469471
# std        10.546005   16234.782983       3.536698       0.124267
# min        18.000000    2736.000000       3.000000       0.000000
# 25%        28.000000   14908.000000      10.000000       0.379495
# 50%        34.000000   21229.000000      10.000000       0.461599
# 75%        43.000000   32068.000000      12.000000       0.552396
# max        71.000000  200000.000000      36.000000       1.128291
#
#        monthly_income   credit_count  overdue_credit_count
# count   170746.000000  170746.000000         170746.000000
# mean     40138.258261       1.993394              0.043579
# std      25044.135085       1.792914              0.206014
# min       5000.000000       0.000000              0.000000
# 25%      25000.000000       1.000000              0.000000
# 50%      35000.000000       2.000000              0.000000
# 75%      50000.000000       3.000000              0.000000
# max     950000.000000      21.000000              3.000000

# %%
# Выводим среднее значение
# переменной credit_sum
data3['credit_sum'].mean()
# Out:
# 26095.073779239687

# %%
# Выводим медиану
# переменной credit_sum
data3['credit_sum'].median()
# Out:
# 21229.0

# %%
# Выводим стандартное отклонение
# переменной credit_sum
data3['credit_sum'].std()
# Out:
# 16234.782983145278

# %%
# Выводим моду переменной education
data3['education'].mode()
# Out:
# 0    SCH
# dtype: object

# %%
# Выделяем категориальные переменные в отдельную группу
cat_columns = [c for c in data3.columns if data3[c].dtype.name == 'object']

# %%
# Выводим информацию о категориальных переменных
data3[cat_columns].describe()
# Out:
#         gender marital_status job_position  tariff_id education  \
# count   170746         170746       170746     170746    170746
# unique       2              6           18         33         5
# top          F            MAR          SPC          2       SCH
# freq     88697          93955       134680      69355     87539
#
#              living_region  open_account_flg
# count               170746            170746
# unique                  82                 2
# top     МОСКОВСКАЯ ОБЛАСТЬ                 0
# freq                 12844            140690

# %%
# Вычислим корреляцию между credit_sum
# и monthly_income
data3['credit_sum'].corr(data3['monthly_income'])
# Out:
# 0.35149268750181273

# %%
# Выводим парные корреляции переменных
data3.corr()
# Out:
#                            age  credit_sum  credit_month  score_shk  \
# age                   1.000000   -0.096598      0.007099  -0.166282
# credit_sum           -0.096598    1.000000      0.228324   0.054471
# credit_month          0.007099    0.228324      1.000000   0.040397
# score_shk            -0.166282    0.054471      0.040397   1.000000
# monthly_income       -0.014884    0.351493      0.007656  -0.107255
# credit_count          0.165183    0.003783      0.050441  -0.126584
# overdue_credit_count  0.018394   -0.005744      0.006883   0.155085
#
#                       monthly_income  credit_count  overdue_credit_count
# age                        -0.014884      0.165183              0.018394
# credit_sum                  0.351493      0.003783             -0.005744
# credit_month                0.007656      0.050441              0.006883
# score_shk                  -0.107255     -0.126584              0.155085
# monthly_income              1.000000      0.151230              0.035453
# credit_count                0.151230      1.000000              0.184139
# overdue_credit_count        0.035453      0.184139              1.000000

# %%
# Можно визуализировать корреляции с помощью библиотеки seaborn
# Импортируем библиотеку seaborn, предварительно установив 
# ее в Anaconda Prompt с помощью команды 
# conda install -c anaconda seaborn
import seaborn as sns
corr = data3.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# ## Отбор переменных определенного типа

# %%
# отбираем переменные типа object
cat_data = data3.select_dtypes(include=['object'])
cat_data.head()
# Out:
#   gender marital_status job_position tariff_id education  \
# 0      M            MAR          UMN        28       GRD
# 1      F            MAR          UMN         2       GRD
# 2      M            MAR          SPC         2       SCH
# 3      F            DIV          SPC         2       GRD
# 4      M            MAR          SPC         2       SCH
#
#            living_region open_account_flg
# 0     КРАСНОДАРСКИЙ КРАЙ                0
# 1                 МОСКВА                0
# 2    САРАТОВСКАЯ ОБЛАСТЬ                0
# 3  ВОЛГОГРАДСКАЯ ОБЛАСТЬ                0
# 4    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ                0

# %%
# отбираем из переменных типа object все переменные,
# кроме переменной open_account_flg
cat_data_with_cond = cat_data.loc[:, cat_data.columns != 'open_account_flg']
cat_data_with_cond.head()
# Out:
#   gender marital_status job_position tariff_id education  \
# 0      M            MAR          UMN        28       GRD
# 1      F            MAR          UMN         2       GRD
# 2      M            MAR          SPC         2       SCH
# 3      F            DIV          SPC         2       GRD
# 4      M            MAR          SPC         2       SCH
#
#            living_region
# 0     КРАСНОДАРСКИЙ КРАЙ
# 1                 МОСКВА
# 2    САРАТОВСКАЯ ОБЛАСТЬ
# 3  ВОЛГОГРАДСКАЯ ОБЛАСТЬ
# 4    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ

# %%
# отбираем все переменные из исходного набора,
# кроме переменной age
data_with_cond = data3[data3.columns.difference(['age'])]
data_with_cond.head()
# Out:
#    credit_count  credit_month  credit_sum education gender job_position  \
# 0             1            10    59998.00       GRD      M          UMN
# 1             2             6    10889.00       GRD      F          UMN
# 2             5            12    10728.00       SCH      M          SPC
# 3             2            12    12009.09       GRD      F          SPC
# 4             1            10    16908.89       SCH      M          SPC
#
#            living_region marital_status  monthly_income open_account_flg  \
# 0     КРАСНОДАРСКИЙ КРАЙ            MAR         30000.0                0
# 1                 МОСКВА            MAR         43000.0                0
# 2    САРАТОВСКАЯ ОБЛАСТЬ            MAR         23000.0                0
# 3  ВОЛГОГРАДСКАЯ ОБЛАСТЬ            DIV         17000.0                0
# 4    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ            MAR         25000.0                0
#
#    overdue_credit_count  score_shk tariff_id
# 0                     1   0.770249        28
# 1                     0   0.248514         2
# 2                     0   0.459589         2
# 3                     0   0.362536         2
# 4                     0   0.421385         2

# %%
# отбираем переменные типа object и float
catreal_data = data3.select_dtypes(include=['object', 'float'])
catreal_data.head()
# Out:
#   gender marital_status job_position  credit_sum tariff_id  score_shk  \
# 0      M            MAR          UMN    59998.00        28   0.770249
# 1      F            MAR          UMN    10889.00         2   0.248514
# 2      M            MAR          SPC    10728.00         2   0.459589
# 3      F            DIV          SPC    12009.09         2   0.362536
# 4      M            MAR          SPC    16908.89         2   0.421385
#
#   education          living_region  monthly_income open_account_flg
# 0       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0                0
# 1       GRD                 МОСКВА         43000.0                0
# 2       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0                0
# 3       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0                0
# 4       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0                0

# %%
# отбираем переменные типа int
int_data = data3.select_dtypes(include=['int'])
int_data.head()
# Out:
#    age  credit_count  overdue_credit_count
# 0   48             1                     1
# 1   28             2                     0
# 2   32             5                     0
# 3   27             2                     0
# 4   45             1                     0

# %%
# отбираем только количественные переменные
numeric_data = data3.select_dtypes(include=[np.number])
numeric_data.head()
# Out:
#    age  credit_sum  credit_month  score_shk  monthly_income  credit_count  \
# 0   48    59998.00            10   0.770249         30000.0             1
# 1   28    10889.00             6   0.248514         43000.0             2
# 2   32    10728.00            12   0.459589         23000.0             5
# 3   27    12009.09            12   0.362536         17000.0             2
# 4   45    16908.89            10   0.421385         25000.0             1
#
#    overdue_credit_count
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %% [markdown]
# ## Cоздание новых переменных

# %% [markdown]
# ### Создаем переменную, у которой значения основаны на значениях другой переменной

# %%
# Выводим уникальные значения исходной переменной, в данном случае - значения переменной job_position
print(data3['job_position'].unique())
# Out:
# ['UMN' 'SPC' 'INP' 'DIR' 'ATP' 'PNA' 'BIS' 'WOI' 'NOR' 'WRK' 'WRP' 'PNV'
#  'BIU' 'PNI' 'HSK' 'PNS' 'INV' 'ONB']

# %%
# Затем создаем словарь, в котором ключом будет значение исходной переменной job_position, 
# а значением - значение будущей переменной avrzarplata
dct = {'UMN': 51000, 'SPC': 63000, 'INP': 55000, 'DIR': 60000, 
       'ATP': 46000, 'PNA': 71000, 'BIS': 86000, 'WOI': 76000,
       'NOR': 54000,'WRK': 77000, 'WRP': 75000, 'PNV': 67000, 
       'BIU': 43000, 'PNI': 69000, 'HSK': 74000, 'PNS': 44000, 
       'INV': 88000, 'ONB': 62000}
# Создаем новую переменную avrzarplata, у которой значения сопоставлены значениям переменной job_position
data3['avrzarplata'] = data3['job_position'].map(dct)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata
# 0                     1                0        51000
# 1                     0                0        51000
# 2                     0                0        63000
# 3                     0                0        63000
# 4                     0                0        63000

# %% [markdown]
# ### Создаем переменную, которая является отношением двух переменных

# %%
# Создаем переменную, которая является отношением суммы кредита к ежемесячному заработку
data3['ratio'] = data3['credit_sum'] / data3['monthly_income']
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio
# 0                     1                0        51000  1.999933
# 1                     0                0        51000  0.253233
# 2                     0                0        63000  0.466435
# 3                     0                0        63000  0.706417
# 4                     0                0        63000  0.676356

# %% [markdown]
# ### Создаем переменную, у которой каждое значение - частота наблюдений в категории переменной

# %%
# Создаем переменную region_cnt, у которой каждое значение - частота наблюдений в категории переменной living_region
data3['region_cnt'] = data3['living_region'].map(data3['living_region'].value_counts())
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155

# %% [markdown]
# ### Создаем переменную, у которой каждое значение - среднее значение количественной переменной, взятое по уровню категориальной переменной

# %%
# Пишем функцию, создающую переменную, у которой каждое значение будет средним значением количественной
# переменной (real_feature), взятым по уровню категориальной переменной (cat_feature)
def code_mean(data, cat_feature, real_feature):
    return (data[cat_feature].map(data.groupby(cat_feature)[real_feature].mean()))

# Создаем переменную, у которой каждое значение - среднее значение monthly_income 
# в категории переменной living_region
data3['region_mean_income'] = code_mean(data3, 'living_region', 'monthly_income')
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income
# 0        37260.771993
# 1        62696.116618
# 2        31110.902717
# 3        31301.444396
# 4        33759.671775

# %% [markdown]
# ### Создаем категориальную переменную в результате конъюнкции двух переменных

# %%
# Пишем функцию, которая создает переменную в результате конъюнкции
# переменных feature1 и feature2
def make_conj(data, feature1, feature2):
    data[feature1 + ' + ' + feature2] = data[feature1].astype(str) + ' + ' + data[feature2].astype(str)
    return (data)
make_conj(data3, 'education', 'marital_status')
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status
# 0        37260.771993                  GRD + MAR
# 1        62696.116618                  GRD + MAR
# 2        31110.902717                  SCH + MAR
# 3        31301.444396                  GRD + DIV
# 4        33759.671775                  SCH + MAR

# %% [markdown]
# ### Создаем переменную, у которой каждое значение - логарифм значения количественной переменной

# %%
# Создаем переменную log_income, у которой каждое значение - логарифм значения
# переменной monthly_income
data3['log_income'] = np.log(data3['monthly_income'])
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income
# 0        37260.771993                  GRD + MAR   10.308953
# 1        62696.116618                  GRD + MAR   10.668955
# 2        31110.902717                  SCH + MAR   10.043249
# 3        31301.444396                  GRD + DIV    9.740969
# 4        33759.671775                  SCH + MAR   10.126631

# %% [markdown]
# ### Создаем количественную переменную, у которой каждое значение - усредненное значение нескольких количественных переменных

# %%
# Создаем переменную mean_age_tenure, у которой каждое значение - усредненное значение 
# переменных age и credit_month 
data3['mean_age_tenure'] = data3[['age', 'credit_month']].mean(axis=1)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5

# %% [markdown]
# ### Выполняем категоризацию (биннинг) количественной переменной на основе интервалов, заданных вручную

# %%
# Вычисляем минимальное значение переменной monthly_income
min_income = data3['monthly_income'].min()
min_income
# Out:
# 5000.0

# %%
# Вычисляем максимальное значение переменной monthly_income
max_income = data3['monthly_income'].max()
max_income
# Out:
# 950000.0

# %%
# Задаем точки, в которых будут находится границы категорий 
# (от 5000 до 50000, от 50000 до 200000, от 200000 до 950000) 
bins = [-np.inf, 50000, 200000, np.inf]
# Задаем метки для категорий будущей переменной
group_names = ['Low', 'Average', 'High']
# Осуществляем биннинг переменной monthly_income 
# и записываем результаты в новую переменную incomecat
data3['incomecat'] = pd.cut(data3['monthly_income'], bins, labels=group_names)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat
# 0       Low
# 1       Low
# 2       Low
# 3       Low
# 4       Low

# %%
# Пишем функцию, которая категоризирует
# переменную monthly_income
def income_category(monthly_income):
    '''
    < 20000 -> 1
    >= 20000, <40000 -> 2
    >= 40000 -> 3
    '''
    if monthly_income < 20000:
        return 1
    elif monthly_income < 40000:
        return 2
    else:
        return 3

# %%
# создаем новую переменную income_category
income_categories = [income_category(monthly_income) for monthly_income in data3.monthly_income]
data3['income_category'] = income_categories
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category
# 0       Low                2
# 1       Low                3
# 2       Low                2
# 3       Low                1
# 4       Low                2

# %%
# а еще можно воспользоваться методом .apply()
data3['income_category2'] = data3['monthly_income'].apply(income_category)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2
# 0       Low                2                 2
# 1       Low                3                 3
# 2       Low                2                 2
# 3       Low                1                 1
# 4       Low                2                 2

# %% [markdown]
# ### Выполняем категоризацию (биннинг) количественной переменной на основе децилей

# %%
# Осуществляем биннинг переменной monthly_income на основе децилей и записываем результаты 
# в новую переменную income_decile, не создавая меток категорий
data3['income_decile'] = pd.qcut(data3['monthly_income'], 10, labels=False)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile
# 0       Low                2                 2              3
# 1       Low                3                 3              6
# 2       Low                2                 2              1
# 3       Low                1                 1              0
# 4       Low                2                 2              2

# %% [markdown]
# ### Создаем бинарную переменную на основе значений количественной переменной

# %%
# создаем новую переменную retired, которая принимает значение "Yes",
# если значение переменной age больше 60, и значение "No" в противном случае
data3['retired'] = np.where(data3['age']>=60, 'Yes', 'No')
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile retired
# 0       Low                2                 2              3      No
# 1       Low                3                 3              6      No
# 2       Low                2                 2              1      No
# 3       Low                1                 1              0      No
# 4       Low                2                 2              2      No

# %% [markdown]
# ### Создаем бинарную переменную на основе значений количественных переменных

# %%
# создаем новую переменную age_inc, которая принимает значение "Yes",
# если речь идет о клиентах старше 35 лет и с суммой кредита свыше 10000, 
# и значение "No" в противном случае
data3['age_inc'] = np.where((data3['age'] > 35) & (data3['credit_sum'] > 10000), 'Yes', 'No')
data3.head(10)
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
# 5      F   37            MAR          SPC    26788.00            10         2
# 6      M   36            MAR          SPC    10317.00             6        25
# 7      F   26            UNM          SPC    47878.00            10         2
# 8      M   23        Пропуск          SPC    37577.16            12        28
# 9      F   32            UNM          SPC    26268.00            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
# 5   0.484203       SCH    СТАВРОПОЛЬСКИЙ КРАЙ         30000.0             0
# 6   0.276012       SCH  НИЖЕГОРОДСКАЯ ОБЛАСТЬ         28000.0             3
# 7   0.512525       GRD     МОСКОВСКАЯ ОБЛАСТЬ         60000.0             3
# 8   0.642267       SCH      ТЮМЕНСКАЯ ОБЛАСТЬ         50000.0             3
# 9   0.465026       GRD    СТАВРОПОЛЬСКИЙ КРАЙ         39500.0             7
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
# 5                     0                0        63000  0.892933        4617
# 6                     0                0        63000  0.368464        3695
# 7                     0                0        63000  0.797967       12844
# 8                     0                0        63000  0.751543        8735
# 9                     0                0        63000  0.665013        4617
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
# 5        32335.763916                  SCH + MAR   10.308953             23.5
# 6        34254.011096                  SCH + MAR   10.239960             21.0
# 7        53064.730458                  GRD + UNM   11.002100             18.0
# 8        48550.896508              SCH + Пропуск   10.819778             17.5
# 9        32335.763916                  GRD + UNM   10.584056             21.0
#
#   incomecat  income_category  income_category2  income_decile retired age_inc
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
# 5       Low                2                 2              3      No     Yes
# 6       Low                2                 2              3      No     Yes
# 7   Average                3                 3              8      No      No
# 8       Low                3                 3              7      No      No
# 9       Low                2                 2              5      No      No

# %%
# создаем новую переменную age_inc, которая принимает значение "Yes",
# если речь идет о клиентах старше 35 лет или с суммой кредита свыше 13000, 
# и значение "No" в противном случае
data3['age_inc2'] = np.where((data3['age'] > 35) | (data3['credit_sum'] > 13000), 'Yes', 'No')
data3.head(10)
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
# 5      F   37            MAR          SPC    26788.00            10         2
# 6      M   36            MAR          SPC    10317.00             6        25
# 7      F   26            UNM          SPC    47878.00            10         2
# 8      M   23        Пропуск          SPC    37577.16            12        28
# 9      F   32            UNM          SPC    26268.00            10         2
#
#    score_shk education          living_region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
# 5   0.484203       SCH    СТАВРОПОЛЬСКИЙ КРАЙ         30000.0             0
# 6   0.276012       SCH  НИЖЕГОРОДСКАЯ ОБЛАСТЬ         28000.0             3
# 7   0.512525       GRD     МОСКОВСКАЯ ОБЛАСТЬ         60000.0             3
# 8   0.642267       SCH      ТЮМЕНСКАЯ ОБЛАСТЬ         50000.0             3
# 9   0.465026       GRD    СТАВРОПОЛЬСКИЙ КРАЙ         39500.0             7
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
# 5                     0                0        63000  0.892933        4617
# 6                     0                0        63000  0.368464        3695
# 7                     0                0        63000  0.797967       12844
# 8                     0                0        63000  0.751543        8735
# 9                     0                0        63000  0.665013        4617
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
# 5        32335.763916                  SCH + MAR   10.308953             23.5
# 6        34254.011096                  SCH + MAR   10.239960             21.0
# 7        53064.730458                  GRD + UNM   11.002100             18.0
# 8        48550.896508              SCH + Пропуск   10.819778             17.5
# 9        32335.763916                  GRD + UNM   10.584056             21.0
#
#   incomecat  income_category  income_category2  income_decile retired age_inc  \
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
# 5       Low                2                 2              3      No     Yes
# 6       Low                2                 2              3      No     Yes
# 7   Average                3                 3              8      No      No
# 8       Low                3                 3              7      No      No
# 9       Low                2                 2              5      No      No
#
#   age_inc2
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes
# 5      Yes
# 6      Yes
# 7      Yes
# 8      Yes
# 9      Yes

# %% [markdown]
# ## Переименование переменных

# %%
# Переименовываем переменную living_region в новую переменную region
data3.rename(columns={'living_region':'region'}, inplace=True)
data3.head()
# Out:
#   gender  age marital_status job_position  credit_sum  credit_month tariff_id  \
# 0      M   48            MAR          UMN    59998.00            10        28
# 1      F   28            MAR          UMN    10889.00             6         2
# 2      M   32            MAR          SPC    10728.00            12         2
# 3      F   27            DIV          SPC    12009.09            12         2
# 4      M   45            MAR          SPC    16908.89            10         2
#
#    score_shk education                 region  monthly_income  credit_count  \
# 0   0.770249       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1   0.248514       GRD                 МОСКВА         43000.0             2
# 2   0.459589       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3   0.362536       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4   0.421385       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile retired age_inc  \
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
#
#   age_inc2
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes

# %%
# Переименовываем переменную marital_status в marstatus, а переменную job_position - в job
data3 = data3.rename(columns={'marital_status': 'marstatus', 'job_position': 'job'})
data3.head()
# Out:
#   gender  age marstatus  job  credit_sum  credit_month tariff_id  score_shk  \
# 0      M   48       MAR  UMN    59998.00            10        28   0.770249
# 1      F   28       MAR  UMN    10889.00             6         2   0.248514
# 2      M   32       MAR  SPC    10728.00            12         2   0.459589
# 3      F   27       DIV  SPC    12009.09            12         2   0.362536
# 4      M   45       MAR  SPC    16908.89            10         2   0.421385
#
#   education                 region  monthly_income  credit_count  \
# 0       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1       GRD                 МОСКВА         43000.0             2
# 2       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile retired age_inc  \
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
#
#   age_inc2
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes

# %% [markdown]
# ## Переименование категорий переменных

# %%
# Переименуем категории переменной marstatus
d = {'MAR':'Married', 'DIV':'Divorced', 'WID':'Widowed', 'UNM':'Unmarried', 'CIV':'Civil union'}
data3['marstatus'] = data3['marstatus'].map(d)
data3.head()
# Out:
#   gender  age marstatus  job  credit_sum  credit_month tariff_id  score_shk  \
# 0      M   48   Married  UMN    59998.00            10        28   0.770249
# 1      F   28   Married  UMN    10889.00             6         2   0.248514
# 2      M   32   Married  SPC    10728.00            12         2   0.459589
# 3      F   27  Divorced  SPC    12009.09            12         2   0.362536
# 4      M   45   Married  SPC    16908.89            10         2   0.421385
#
#   education                 region  monthly_income  credit_count  \
# 0       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1       GRD                 МОСКВА         43000.0             2
# 2       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile retired age_inc  \
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
#
#   age_inc2
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes

# %%
# Переименуем категории переменной marstatus другим способом
f = {'Married':'Mar', 'Unmarried': 'Unm', 'Divorced':'Div', 'Widowed':'Wid', 'Civil union': 'Civ'}
data3 = data3.replace({'marstatus': f})
data3.head()
# Out:
#   gender  age marstatus  job  credit_sum  credit_month tariff_id  score_shk  \
# 0      M   48       Mar  UMN    59998.00            10        28   0.770249
# 1      F   28       Mar  UMN    10889.00             6         2   0.248514
# 2      M   32       Mar  SPC    10728.00            12         2   0.459589
# 3      F   27       Div  SPC    12009.09            12         2   0.362536
# 4      M   45       Mar  SPC    16908.89            10         2   0.421385
#
#   education                 region  monthly_income  credit_count  \
# 0       GRD     КРАСНОДАРСКИЙ КРАЙ         30000.0             1
# 1       GRD                 МОСКВА         43000.0             2
# 2       SCH    САРАТОВСКАЯ ОБЛАСТЬ         23000.0             5
# 3       GRD  ВОЛГОГРАДСКАЯ ОБЛАСТЬ         17000.0             2
# 4       SCH    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ         25000.0             1
#
#    overdue_credit_count open_account_flg  avrzarplata     ratio  region_cnt  \
# 0                     1                0        51000  1.999933        8355
# 1                     0                0        51000  0.253233        9261
# 2                     0                0        63000  0.466435        2282
# 3                     0                0        63000  0.706417        2293
# 4                     0                0        63000  0.676356        5155
#
#    region_mean_income education + marital_status  log_income  mean_age_tenure  \
# 0        37260.771993                  GRD + MAR   10.308953             29.0
# 1        62696.116618                  GRD + MAR   10.668955             17.0
# 2        31110.902717                  SCH + MAR   10.043249             22.0
# 3        31301.444396                  GRD + DIV    9.740969             19.5
# 4        33759.671775                  SCH + MAR   10.126631             27.5
#
#   incomecat  income_category  income_category2  income_decile retired age_inc  \
# 0       Low                2                 2              3      No     Yes
# 1       Low                3                 3              6      No      No
# 2       Low                2                 2              1      No      No
# 3       Low                1                 1              0      No      No
# 4       Low                2                 2              2      No     Yes
#
#   age_inc2
# 0      Yes
# 1       No
# 2       No
# 3       No
# 4      Yes

# %% [markdown]
# ## Группировка данных

# %%
print(data3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170746 entries, 0 to 170745
# Data columns (total 28 columns):
# gender                        170746 non-null object
# age                           170746 non-null int32
# marstatus                     170744 non-null object
# job                           170746 non-null object
# credit_sum                    170746 non-null float64
# credit_month                  170746 non-null int64
# tariff_id                     170746 non-null object
# score_shk                     170746 non-null float64
# education                     170746 non-null object
# region                        170746 non-null object
# monthly_income                170746 non-null float64
# credit_count                  170746 non-null int32
# overdue_credit_count          170746 non-null int32
# open_account_flg              170746 non-null object
# avrzarplata                   170746 non-null int64
# ratio                         170746 non-null float64
# region_cnt                    170746 non-null int64
# region_mean_income            170746 non-null float64
# education + marital_status    170746 non-null object
# log_income                    170746 non-null float64
# mean_age_tenure               170746 non-null float64
# incomecat                     170746 non-null category
# income_category               170746 non-null int64
# income_category2              170746 non-null int64
# income_decile                 170746 non-null int64
# retired                       170746 non-null object
# age_inc                       170746 non-null object
# age_inc2                      170746 non-null object
# dtypes: category(1), float64(7), int32(3), int64(6), object(11)
# memory usage: 33.4+ MB
# None

# %%
# Вычислим средний месячный заработок для каждого значения переменной job_position
data3.groupby('job')['monthly_income'].mean()
# Out:
# job
# ATP    29717.366894
# BIS    59556.530674
# BIU    41508.730159
# DIR    67521.516267
# HSK    31250.000000
# INP    65553.941909
# INV    25680.000000
# NOR    36650.975791
# ONB    17000.000000
# PNA    22575.575846
# PNI    20367.692308
# PNS    39591.666667
# PNV    23335.300000
# SPC    38111.610009
# UMN    49431.941326
# WOI    35983.678977
# WRK    37029.185976
# WRP    38859.827273
# Name: monthly_income, dtype: float64

# %%
# Посмотрим распределение значений переменной open_account_flg в каждом уровне
# переменной job
group_by_job = data3.groupby(['job','open_account_flg'])
group_by_job.size()
# Out:
# job  open_account_flg
# ATP  0                     1984
#      1                      807
# BIS  0                     4706
#      1                      885
# BIU  0                       80
#      1                       46
# DIR  0                     3195
#      1                      555
# HSK  0                        6
#      1                        2
# INP  0                      174
#      1                       67
# INV  0                        1
#      1                        4
# NOR  0                      343
#      1                      194
# ONB  1                        1
# PNA  0                     2618
#      1                     1489
# PNI  0                       45
#      1                       20
# PNS  0                        6
#      1                        6
# PNV  0                       31
#      1                        9
# SPC  0                   112277
#      1                    22403
# UMN  0                    14334
#      1                     3340
# WOI  0                      268
#      1                       84
# WRK  0                      535
#      1                      121
# WRP  0                       87
#      1                       23
# dtype: int64

# %% [markdown]
# ## Визуальный анализ данных

# %% [markdown]
# ### Построение графиков с помощью matplotlib

# %% [markdown]
# ### Построение гистограммы

# %%
# Строим гистограмму распределения по возрасту
data3.age.hist()
plt.title('Гистограмма распределения по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Частота')
# Out:
# Text(0,0.5,'Частота')

# %% [markdown]
# ### Построение круговой диаграммы

# %%
# Вычисляем частоты значений переменной incomecat, на основе которых
# мы сформируем сектора будущей круговой диаграммы
counts = data3['marstatus'].value_counts()
counts
# Out:
# Mar    93955
# Unm    52148
# Div    16970
# Civ     4196
# Wid     3475
# Name: marstatus, dtype: int64

# %%
# Создаем список из 3 цветов по количеству будущих секторов
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B"]

# Создаем круговую диаграмму
plt.pie(
    # используем частоты значений переменной incomecat
    counts,
    # задаем список меток
    labels=["Mar", "Unm", "Div", "Civ", "Wid"],
    # без использования тени
    shadow=False,
    # задаем список цветов
    colors=colors,
    # один сектор отделяем от других
    explode=(0, 0, 0, 0, 0.20),
    # задаем начальный угол в градусах
    startangle=90,
    # выводим значения в виде процентов
    autopct='%1.1f%%'
    )

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Построение простой столбиковой диаграммы

# %%
my_bar_plot = counts.plot(kind='bar')

# %% [markdown]
# ### Построение кластеризованной столбиковой диаграммы

# %%
# по каждой категории переменной marstatus посмотрим,
# сколько клиентов открыло счет в ТКС и сколько не открыло
pd.crosstab(data3.marstatus, data.open_account_flg).plot.barh(stacked=False)

# %% [markdown]
# ### Построение состыкованной столбиковой диаграммы

# %%
pd.crosstab(data3.marstatus, data.open_account_flg).plot.barh(stacked=True)
